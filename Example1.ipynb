# %%
list1=['Bolt','Tyson','Gatlin','Powell']

# %%
print(list1)
# Out:
# ['Bolt', 'Tyson', 'Gatlin', 'Powell']

# %%
tup1=('Gaza City','Jenin','Ramala')
print(tup1)
# Out:
# ('Gaza City', 'Jenin', 'Ramala')

# %%
#Math libary

# %%
import math
math.sin(math.pi)
# Out:
# 1.2246467991473532e-16

# %%
math.pow(2,6)
# Out:
# 64.0

# %%
def cal(x):
    y=math.pow(x,3)-2*x-5
    return y
print(cal(2))
# Out:
# -1.0

# %%
na=input("Enter Your Name :")
# Out:
# Enter Your Name :Daminda

# %%
print(na)
# Out:
# Daminda
