# %%
import pandas as pd

# %%
duration=[10.58,10.63,10.65]
time=pd.Series(duration)

# %%
print(time)
# Out:
# 0    10.58
# 1    10.63
# 2    10.65
# dtype: float64

# %%
print(time[1])
# Out:
# 10.63

# %%
data={"Bolt":10.58,"Tyson":10.63,"Blake":10.65}

# %%
var1=pd.Series(data)

# %%
print(var1)
# Out:
# Bolt     10.58
# Tyson    10.63
# Blake    10.65
# dtype: float64

# %%
data1={"names":['Bolt','Tyson','Blake','Powell'],
       'duration':[10.58,10.63,10.65,10.70],"country":['JA','US','JA','US']}

# %%
df1=pd.DataFrame(data1)
print(df1)
# Out:
# {'names': ['Bolt', 'Tyson', 'Blake', 'Powell'], 'duration': [10.58, 10.63, 10.65, 10.7], 'country': ['JA', 'US', 'JA', 'US']}
