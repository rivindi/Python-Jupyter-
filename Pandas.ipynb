# %%
import pandas as pd

# %%
duration=[10.58,10.63,10.65]
time=pd.Series(duration)

# %%
print(time)
# Out:
# 0    10.58
# 1    10.63
# 2    10.65
# dtype: float64

# %%
print(time[1])
# Out:
# 10.63

# %%
data={"Bolt":10.58,"Tyson":10.63,"Blake":10.65}

# %%
var1=pd.Series(data)

# %%
print(var1)
# Out:
# Bolt     10.58
# Tyson    10.63
# Blake    10.65
# dtype: float64

# %%
data1={"names":['Bolt','Tyson','Blake','Powell'],
       'duration':[10.58,10.63,10.65,10.70],"country":['JA','US','JA','US']}

# %%
df1=pd.DataFrame(data1)
print(df1)
# Out:
#     names  duration country
# 0    Bolt     10.58      JA
# 1   Tyson     10.63      US
# 2   Blake     10.65      JA
# 3  Powell     10.70      US

# %%
print(df1['names'])
# Out:
# 0      Bolt
# 1     Tyson
# 2     Blake
# 3    Powell
# Name: names, dtype: object

# %%
print(df1.loc[0:2])
# Out:
#    names  duration country
# 0   Bolt     10.58      JA
# 1  Tyson     10.63      US
# 2  Blake     10.65      JA

# %%
df1['duration'].plot()
# Out:
# <AxesSubplot:>

# %%
df2=pd.read_csv("vac.csv")

# %%
print(df2.head(100))
# Out:
#      location        date                                           vaccine  \
# 0   Sri Lanka  2021-01-28                                Oxford/AstraZeneca
# 1   Sri Lanka  2021-01-29                                Oxford/AstraZeneca
# 2   Sri Lanka  2021-01-30                                Oxford/AstraZeneca
# 3   Sri Lanka  2021-01-31                                Oxford/AstraZeneca
# 4   Sri Lanka  2021-02-01                                Oxford/AstraZeneca
# ..        ...         ...                                               ...
# 95  Sri Lanka  2021-05-31  Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V
# 96  Sri Lanka  2021-06-01  Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V
# 97  Sri Lanka  2021-06-02  Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V
# 98  Sri Lanka  2021-06-05  Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V
# 99  Sri Lanka  2021-06-06  Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V
#
# ...
